# %% [markdown]
# # 1. 라이브러리 설치 및 import

# %% [markdown]
# ## 1.1. 라이브러리 설치

# %%
# !pip install mediapipe    # Mediapipe 설치
# Out:
# Requirement already satisfied: mediapipe in /usr/local/lib/python3.11/dist-packages (0.10.21)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.4.0)
# Requirement already satisfied: attrs>=19.1.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (25.2.10)
# Requirement already satisfied: jax in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: jaxlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mediapipe) (3.10.0)
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (1.26.4)
# Requirement already satisfied: opencv-contrib-python in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.11.0.86)
# Requirement already satisfied: protobuf<5,>=4.25.3 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (4.25.8)
# Requirement already satisfied: sounddevice>=0.4.4 in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.5.2)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.11/dist-packages (from mediapipe) (0.2.0)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice>=0.4.4->mediapipe) (1.17.1)
# Requirement already satisfied: ml_dtypes>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (0.4.1)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (3.4.0)
# Requirement already satisfied: scipy>=1.11.1 in /usr/local/lib/python3.11/dist-packages (from jax->mediapipe) (1.15.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapipe) (2.9.0.post0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.22)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.17.0)

# %% [markdown]
# ## 1.2. 라이브러리 import

# %%
import mediapipe as mp                                  # 손 랜드마크 오버레이 목적
import os
import pathlib
import time
from tqdm import tqdm                                   # 진행률 표시
import cv2                                              # OpenCV: 이미지 처리
import torch
import torchvision as tv                                # PyTorch 비전 관련 기능
from torch import nn
from torchvision import transforms as T                 # 이미지 전처리
from torch.utils.data import DataLoader, random_split
from torch.amp import autocast, GradScaler              # Mixed Precision 학습
import numpy as np
from PIL import Image                                   # 이미지 입출력
from google.colab import drive                          # Google Drive 마운트

# %% [markdown]
# # 2. Google Colab 마운트 및 데이터 압축 해제

# %%
drive.mount('/content/drive')
# !tar -C /content/drive/MyDrive -cf - asl_alphabet_train | tar -C /tmp -xvf -
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
# asl_alphabet_train/nothing/nothing1751.jpg
# tar: asl_alphabet_train/nothing/nothing1751.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2802.jpg
# tar: asl_alphabet_train/nothing/nothing2802.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1260.jpg
# tar: asl_alphabet_train/nothing/nothing1260.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1906.jpg
# tar: asl_alphabet_train/nothing/nothing1906.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing1156.jpg
# asl_alphabet_train/nothing/nothing1156.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing1126.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1126.jpg
# asl_alphabet_train/nothing/nothing2292.jpg
# tar: asl_alphabet_train/nothing/nothing2292.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2549.jpg
# tar: asl_alphabet_train/nothing/nothing2549.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1217.jpg
# tar: asl_alphabet_train/nothing/nothing1217.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1696.jpg
# tar: asl_alphabet_train/nothing/nothing1696.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2110.jpg
# tar: asl_alphabet_train/nothing/nothing2110.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing2345.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2345.jpg
# asl_alphabet_train/nothing/nothing2331.jpg
# tar: asl_alphabet_train/nothing/nothing2331.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2283.jpg
# tar: asl_alphabet_train/nothing/nothing2283.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1793.jpg
# tar: asl_alphabet_train/nothing/nothing1793.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing960.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing960.jpg
# asl_alphabet_train/nothing/nothing466.jpg
# tar: asl_alphabet_train/nothing/nothing466.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2630.jpg
# tar: asl_alphabet_train/nothing/nothing2630.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2506.jpg
# tar: asl_alphabet_train/nothing/nothing2506.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing756.jpg
# tar: asl_alphabet_train/nothing/nothing756.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1856.jpg
# tar: asl_alphabet_train/nothing/nothing1856.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing79.jpg
# tar: asl_alphabet_train/nothing/nothing79.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing2794.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2794.jpg
# tar: asl_alphabet_train/nothing/nothing495.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing495.jpg
# asl_alphabet_train/nothing/nothing748.jpg
# tar: asl_alphabet_train/nothing/nothing748.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1675.jpg
# tar: asl_alphabet_train/nothing/nothing1675.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2974.jpg
# tar: asl_alphabet_train/nothing/nothing2974.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2911.jpg
# tar: asl_alphabet_train/nothing/nothing2911.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing2284.jpg
# asl_alphabet_train/nothing/nothing2284.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing561.jpg
# tar: asl_alphabet_train/nothing/nothing561.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing650.jpg
# tar: asl_alphabet_train/nothing/nothing650.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1134.jpg
# tar: asl_alphabet_train/nothing/nothing1134.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing1980.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1980.jpg
# asl_alphabet_train/nothing/nothing673.jpg
# tar: asl_alphabet_train/nothing/nothing673.jpg: file changed as we read it
# asl_alphabet_train/nothing/noth
jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2681.jpg
# tar: asl_alphabet_train/nothing/nothing2681.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1205.jpg
# tar: asl_alphabet_train/nothing/nothing1205.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1261.jpg
# tar: asl_alphabet_train/nothing/nothing1261.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing2513.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2513.jpg
# asl_alphabet_train/nothing/nothing2299.jpg
# tar: asl_alphabet_train/nothing/nothing2299.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing707.jpg
# tar: asl_alphabet_train/nothing/nothing707.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2073.jpg
# tar: asl_alphabet_train/nothing/nothing2073.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing525.jpg
# tar: asl_alphabet_train/nothing/nothing525.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2574.jpg
# tar: asl_alphabet_train/nothing/nothing2574.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2998.jpg
# tar: asl_alphabet_train/nothing/nothing2998.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing2067.jpg
# tar: asl_alphabet_train/nothing/nothing2067.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing835.jpg
# tar: asl_alphabet_train/nothing/nothing835.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing1337.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1337.jpg
# asl_alphabet_train/nothing/nothing1644.jpg
# tar: asl_alphabet_train/nothing/nothing1644.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1103.jpg
# tar: asl_alphabet_train/nothing/nothing1103.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1910.jpg
# tar: asl_alphabet_train/nothing/nothing1910.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing1835.jpg
# tar: asl_alphabet_train/nothing/nothing1835.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing2880.jpg
# asl_alphabet_train/nothing/nothing2880.jpg: file changed as we read it
# tar: asl_alphabet_train/nothing/nothing928.jpg: file changed as we read itasl_alphabet_train/nothing/nothing928.jpg
#
# tar: asl_alphabet_train/nothing/nothing754.jpg: file changed as we read it
# asl_alphabet_train/nothing/nothing754.jpg

# %% [markdown]
# # 3. 데이터 증강 및 랜드마크 오버레이(overlay)

# %% [markdown]
# ## 3.1. 원본 데이터(src) 경로와 증강/오버레이 결과 저장 경로 설정

# %%
SRC_ROOT = '/tmp/asl_alphabet_train'
AUG_ROOT = '/tmp/asl_alphabet_augmented'
DST_ROOT = '/tmp/asl_alphabet_augmented_overlayed'
NUM_AUG = 3      # 원본 이미지 당 생성할 증강본 개수

# %% [markdown]
# ## 3.2. 증강(transform) 정의: 랜덤 수평 뒤집기, 회전, 색상 변경

# %%
aug_transform = T.Compose([
    T.RandomHorizontalFlip(),
    T.RandomRotation(15),
    T.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
])

# %% [markdown]
# ## 3.3. 출력 디렉터리 생성(AUG_ROOT, DST_ROOT)에 클래스 별 폴더 생성

# %%
for d in (AUG_ROOT, DST_ROOT):
    for cls in os.listdir(SRC_ROOT):
        os.makedirs(os.path.join(d, cls), exist_ok=True)

# %% [markdown]
# ## 3.4. Mediapipe Hands 설정: 최대 1 개 손 검출, 신뢰도 기준 설정

# %%
hands = mp.solutions.hands.Hands(
    max_num_hands=1,
    min_detection_confidence=0.5,
    min_tracking_confidence=0.5
)
drawing = mp.solutions.drawing_utils    # 랜드마크 그리기 유틸리티

# %% [markdown]
# ## 3.5. 증강 → 오버레이

# %%
for cls in os.listdir(SRC_ROOT):
    src_cls = os.path.join(SRC_ROOT, cls)
    aug_cls = os.path.join(AUG_ROOT, cls)
    dst_cls = os.path.join(DST_ROOT, cls)

    for fn in tqdm(os.listdir(src_cls), desc=f"Aug+Overlay {cls}"):
        src_path = os.path.join(src_cls, fn)
        img_pil = Image.open(src_path).convert('RGB')     # PIL 이미지로 읽기

        # 원본 포함, NUM_AUG만큼 증강본 생성
        variants = [img_pil] + [aug_transform(img_pil) for _ in range(NUM_AUG)]

        for i, img_aug in enumerate(variants):
            # PIL → OpenCV(BGR) 변환
            cv_img = cv2.cvtColor(np.array(img_aug), cv2.COLOR_RGB2BGR)
            # Mediapipe로 손 랜드마크 검출
            res = hands.process(cv2.cvtColor(cv_img, cv2.COLOR_BGR2RGB))
            # 검출된 경우, 랜드마크 및 연결선 오버레이
            if res.multi_hand_landmarks:
                drawing.draw_landmarks(
                    cv_img,
                    res.multi_hand_landmarks[0],
                    mp.solutions.hands.HAND_CONNECTIONS
                )
            # 결과 저장: 원본(_aug0), 증강본(_aug1~NUM_AUG)
            out_name = fn.replace('.jpg', f'_aug{i}.jpg')
            cv2.imwrite(os.path.join(dst_cls, out_name), cv_img)

# 리소스 해제
hands.close()
# Out:
# Aug+Overlay R: 100%|██████████| 3000/3000 [04:11<00:00, 11.94it/s]
# Aug+Overlay U: 100%|██████████| 3000/3000 [04:13<00:00, 11.84it/s]
# Aug+Overlay B: 100%|██████████| 3000/3000 [04:05<00:00, 12.20it/s]
# Aug+Overlay K: 100%|██████████| 3000/3000 [04:02<00:00, 12.36it/s]
# Aug+Overlay G: 100%|██████████| 3000/3000 [04:15<00:00, 11.72it/s]
# Aug+Overlay V: 100%|██████████| 3000/3000 [04:09<00:00, 12.02it/s]
# Aug+Overlay I: 100%|██████████| 3000/3000 [04:08<00:00, 12.08it/s]
# Aug+Overlay N: 100%|██████████| 3000/3000 [04:26<00:00, 11.26it/s]
# Aug+Overlay J: 100%|██████████| 3000/3000 [04:08<00:00, 12.07it/s]
# Aug+Overlay X: 100%|██████████| 3000/3000 [04:08<00:00, 12.07it/s]
# Aug+Overlay D: 100%|██████████| 3000/3000 [03:47<00:00, 13.19it/s]
# Aug+Overlay Y: 100%|██████████| 3000/3000 [04:02<00:00, 12.35it/s]
# Aug+Overlay F: 100%|██████████| 3000/3000 [03:52<00:00, 12.88it/s]
# Aug+Overlay L: 100%|██████████| 3000/3000 [03:52<00:00, 12.91it/s]
# Aug+Overlay Z: 100%|██████████| 3000/3000 [04:14<00:00, 11.78it/s]
# Aug+Overlay S: 100%|██████████| 3000/3000 [04:13<00:00, 11.85it/s]
# Aug+Overlay H: 100%|██████████| 3000/3000 [04:18<00:00, 11.61it/s]
# Aug+Overlay Q: 100%|██████████| 3000/3000 [04:23<00:00, 11.39it/s]
# Aug+Overlay W: 100%|██████████| 3000/3000 [04:11<00:00, 11.92it/s]
# Aug+Overlay del: 100%|██████████| 3000/3000 [04:41<00:00, 10.67it/s]
# Aug+Overlay T: 100%|██████████| 3000/3000 [04:05<00:00, 12.24it/s]
# Aug+Overlay E: 100%|██████████| 3000/3000 [04:05<00:00, 12.20it/s]
# Aug+Overlay C: 100%|██████████| 3000/3000 [04:11<00:00, 11.91it/s]
# Aug+Overlay nothing: 100%|██████████| 3000/3000 [04:19<00:00, 11.57it/s]
# Aug+Overlay M: 100%|██████████| 3000/3000 [04:27<00:00, 11.21it/s]
# Aug+Overlay space: 100%|██████████| 3000/3000 [04:35<00:00, 10.90it/s]
# Aug+Overlay O: 100%|██████████| 3000/3000 [04:08<00:00, 12.05it/s]
# Aug+Overlay P: 100%|██████████| 3000/3000 [04:24<00:00, 11.35it/s]
# Aug+Overlay A: 100%|██████████| 3000/3000 [04:10<00:00, 11.97it/s]

# %% [markdown]
# # 4. train/val split 및 DataLoader 준비

# %% [markdown]
# ## 4.1. 전처리 완료된 이미지 폴더를 pathlib로 지정

# %%
DATA_ROOT = pathlib.Path(DST_ROOT)
mean, std = [0.5]*3, [0.5]*3        # Normalize 파라미터

# %% [markdown]
# ## 4.2. 전체 데이터셋(ImageFolder) 로드 (transform = None)

# %%
full_ds = tv.datasets.ImageFolder(DATA_ROOT, transform=None)

# %% [markdown]
# ## 4.3. Train/Validation을 비율 80:20로 분할, 시드 고정

# %%
n_total = len(full_ds)
n_train = int(0.8 * n_total)
n_val   = n_total - n_train
train_ds, val_ds = random_split(
    full_ds,
    [n_train, n_val],
    generator=torch.Generator().manual_seed(42)
)

# %% [markdown]
# ## 4.4. train/val 전용 transform 할당

# %%
train_ds.dataset.transform = T.Compose([
    T.Resize((224,224)),                    # 입력 크기 맞춤
    T.ToTensor(),
    T.Normalize(mean, std),
])
val_ds.dataset.transform = T.Compose([
    T.Resize((224,224)),
    T.ToTensor(),
    T.Normalize(mean, std),
])

# %% [markdown]
# ## 4.5. DataLoader 생성: 배치, 셔플, 병렬 처리 등 설정

# %%
train_loader = DataLoader(
    train_ds, batch_size=128, shuffle=True,
    num_workers=8, pin_memory=True, drop_last=True
)
val_loader = DataLoader(
    val_ds, batch_size=128, shuffle=False,
    num_workers=8, pin_memory=True
)

print(f"▶ train samples: {len(train_ds)}, val samples: {len(val_ds)}")
# Out:
# ▶ train samples: 278400, val samples: 69600

# %% [markdown]
# # 5. 모델 학습

# %% [markdown]
# ## 5.1. GPU 사용 가능 시 CUDA, 아니면 CPU

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")

# %% [markdown]
# ## 5.2. torchvision 기본 모델(MobileNetV2) 로드, 마지막 FC 레이어 클래스 수에 맞게 교체

# %%
model = tv.models.mobilenet_v2(weights="IMAGENET1K_V1")
model.classifier[1] = nn.Linear(model.last_channel, len(full_ds.classes))
model = model.to(device)

# %% [markdown]
# ## 5.3. PyTorch 2.0 컴파일 기능을 사용하여 속도 최적화(CUDA일 때)

# %%
if device.type == 'cuda':
    model = torch.compile(model)

# %% [markdown]
# ## 5.4. 손실 함수, optimizer, scaler 설정

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.AdamW(model.parameters(), lr=3e-4, weight_decay=1e-4)
scaler    = GradScaler()
EPOCHS    = 10

# %% [markdown]
# ## 5.5. Epoch 별 학습 및 검증 루프

# %%
for epoch in range(1, EPOCHS+1):
    # --- Training ---
    model.train()
    running_loss = 0.0
    t0 = time.time()
    for images, labels in tqdm(train_loader, desc=f"Epoch {epoch}/{EPOCHS} [Train]"):
        images, labels = images.to(device, non_blocking=True), labels.to(device, non_blocking=True)
        optimizer.zero_grad()
        with autocast(device_type='cuda'):
            outputs = model(images)
            loss    = criterion(outputs, labels)
        scaler.scale(loss).backward()
        scaler.step(optimizer)
        scaler.update()
        running_loss += loss.item() * images.size(0)
    avg_loss = running_loss / len(train_ds)

    # --- Validation ---
    model.eval()
    val_loss = 0.0
    correct  = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            val_loss += criterion(outputs, labels).item() * images.size(0)
            preds = outputs.argmax(dim=1)
            correct += (preds == labels).sum().item()
    avg_val_loss = val_loss / len(val_ds)
    val_acc = correct / len(val_ds)

    t1 = time.time()
    print(f"Epoch {epoch} ▶ "
          f"Train Loss: {avg_loss:.4f} | "
          f"Val Loss: {avg_val_loss:.4f} | Val Acc: {val_acc:.4f} | "
          f"Time: {t1-t0:.1f}s")
# Out:
# Using device: cuda
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 101MB/s]
# Epoch 1/10 [Train]: 100%|██████████| 2175/2175 [03:22<00:00, 10.74it/s]
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:194: UserWarning: TensorFloat32 tensor cores for float32 matrix multiplication available but not enabled. Consider setting `torch.set_float32_matmul_precision('high')` for better performance.
#   warnings.warn(
# Epoch 1 ▶ Train Loss: 0.0593 | Val Loss: 0.0083 | Val Acc: 0.9974 | Time: 272.0s
# Epoch 2/10 [Train]: 100%|██████████| 2175/2175 [02:12<00:00, 16.45it/s]
# Epoch 2 ▶ Train Loss: 0.0093 | Val Loss: 0.0085 | Val Acc: 0.9974 | Time: 164.6s
# Epoch 3/10 [Train]: 100%|██████████| 2175/2175 [02:11<00:00, 16.49it/s]
# Epoch 3 ▶ Train Loss: 0.0077 | Val Loss: 0.0032 | Val Acc: 0.9990 | Time: 164.1s
# Epoch 4/10 [Train]: 100%|██████████| 2175/2175 [02:17<00:00, 15.78it/s]
# Epoch 4 ▶ Train Loss: 0.0058 | Val Loss: 0.0039 | Val Acc: 0.9988 | Time: 170.2s
# Epoch 5/10 [Train]: 100%|██████████| 2175/2175 [02:11<00:00, 16.48it/s]
# Epoch 5 ▶ Train Loss: 0.0055 | Val Loss: 0.0032 | Val Acc: 0.9991 | Time: 164.5s
# Epoch 6/10 [Train]: 100%|██████████| 2175/2175 [02:12<00:00, 16.41it/s]
# Epoch 6 ▶ Train Loss: 0.0053 | Val Loss: 0.0087 | Val Acc: 0.9970 | Time: 164.5s
# Epoch 7/10 [Train]: 100%|██████████| 2175/2175 [02:18<00:00, 15.71it/s]
# Epoch 7 ▶ Train Loss: 0.0035 | Val Loss: 0.0020 | Val Acc: 0.9994 | Time: 170.5s
# Epoch 8/10 [Train]: 100%|██████████| 2175/2175 [02:11<00:00, 16.56it/s]
# Epoch 8 ▶ Train Loss: 0.0035 | Val Loss: 0.0054 | Val Acc: 0.9983 | Time: 163.7s
# Epoch 9/10 [Train]: 100%|██████████| 2175/2175 [02:11<00:00, 16.53it/s]
# Epoch 9 ▶ Train Loss: 0.0034 | Val Loss: 0.0036 | Val Acc: 0.9989 | Time: 163.6s
# Epoch 10/10 [Train]: 100%|██████████| 2175/2175 [02:11<00:00, 16.50it/s]
# Epoch 10 ▶ Train Loss: 0.0033 | Val Loss: 0.0026 | Val Acc: 0.9991 | Time: 165.4s

# %% [markdown]
# # 6. 모델 저장

# %%
SAVE_PATH = '/content/drive/MyDrive/asl_model_local.pth'
torch.save(model.state_dict(), SAVE_PATH)
print(f"📝 Saved model to {SAVE_PATH}")
# Out:
# 📝 Saved model to /content/drive/MyDrive/asl_model_local.pth
